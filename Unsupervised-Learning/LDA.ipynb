# %% [markdown]
# # Linear Discriminant Analysis

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.datasets import fetch_covtype

# %% [markdown]
# ## Loading Datasets

# %% [markdown]
# selecting a batch of 5000 rows from the whole dataset

# %%
data = pd.read_csv("/workspaces/Supervised-Machine-Learning/Datasets/covertype.csv")
subset_indices = np.random.choice(data.index, size=5000, replace=False)

# %% [markdown]
# Extracting X and Y Variables

# %%
X = data.drop("Cover_Type", axis=1).iloc[subset_indices]
y = data["Cover_Type"].iloc[subset_indices]

# %% [markdown]
# ## Applying Standard Scalar

# %%
StandardScaler = StandardScaler()
X_scaled = StandardScaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=3245)

# %% [markdown]
# ## Training logistic Regression without LDA

# %%
Model = LogisticRegression(max_iter=1000, random_state=3245)
Model.fit(X_train, y_train)
y_pred = Model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(f"Logistic Regression Accuracy: {accuracy:.4f}")
# Out:
# Logistic Regression Accuracy: 0.7190

# %% [markdown]
# ## Applying LDA Dimensionality Reduction

# %%
lda = LDA(n_components=6)

X_lda = lda.fit_transform(X_scaled, y)

# %% [markdown]
# ## Explained Variance Ratio

# %%
expVar = lda.explained_variance_ratio_

explained_variance_df = pd.DataFrame({
    'LDA Component': [f'LDA {i+1}' for i in range(len(expVar))],
    'Explained Variance Ratio': expVar
})
display(explained_variance_df)
# Out:
#   LDA Component  Explained Variance Ratio
# 0         LDA 1                  0.690692
# 1         LDA 2                  0.186763
# 2         LDA 3                  0.052243
# 3         LDA 4                  0.045882
# 4         LDA 5                  0.013061
# 5         LDA 6                  0.011359

# %%
X_train_lda, X_test_lda, y_train_lda, y_test_lda = train_test_split(X_lda, y, test_size=0.2, random_state=3245)

# %% [markdown]
# ## Training Logistic Regression with LDA

# %%
model_lda = LogisticRegression(max_iter=1000, random_state=3245)
model_lda.fit(X_train_lda, y_train_lda)
y_pred_lda = model_lda.predict(X_test_lda)
accuracy_lda = accuracy_score(y_test_lda, y_pred_lda)

print(f"Logistic Regression Accuracy after LDA: {accuracy_lda:.4f}")
# Out:
# Logistic Regression Accuracy after LDA: 0.7230
